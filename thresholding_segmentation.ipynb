# %% [markdown]
# <a href="https://colab.research.google.com/github/rakhisreginatito/Forward-Machine/blob/main/thresholding_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('logo patrick.jpg')

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=305x411>

# %%
result = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=L size=305x411>

# %%
ret, thresh1 = cv2.threshold(result, 50, 25, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(result, 50, 25, cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(result, 50, 25, cv2.THRESH_TRUNC)
ret, thresh4 = cv2.threshold(result, 50, 25, cv2.THRESH_TOZERO)
ret, thresh5 = cv2.threshold(result, 50, 25, cv2.THRESH_TOZERO_INV)

# %%
cv2_imshow(thresh1)
cv2_imshow(thresh2)
cv2_imshow(thresh3)
cv2_imshow(thresh4)
cv2_imshow(thresh5)
# Out:
# <PIL.Image.Image image mode=L size=305x411>
# <PIL.Image.Image image mode=L size=305x411>
# <PIL.Image.Image image mode=L size=305x411>
# <PIL.Image.Image image mode=L size=305x411>
# <PIL.Image.Image image mode=L size=305x411>
